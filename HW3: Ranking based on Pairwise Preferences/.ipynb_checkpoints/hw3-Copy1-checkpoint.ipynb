# %%
import pandas as pd
import numpy as np
from crowdkit.aggregation import BradleyTerry
from scipy import stats

import random
import itertools
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
movies_imdb = {
    'Interstellar': 8.7,
    'Cloud Atlas': 7.4,
    'Rogue One: A Star Wars Story': 7.8,
    'I Am Legend': 7.2,
    'No Country for Old Men': 8.2,
    'The Martian': 8.0,
    'Shutter Island': 8.2,
    'The Truman Show': 8.2,
    'The Curious Case of Benjamin Button': 7.8,
    'The Pursuit of Happyness': 8.0,     
}

movies_imdb = dict(sorted(movies_imdb.items()))
movies_imdb
# Out:
# {'Cloud Atlas': 7.4,
#  'I Am Legend': 7.2,
#  'Interstellar': 8.7,
#  'No Country for Old Men': 8.2,
#  'Rogue One: A Star Wars Story': 7.8,
#  'Shutter Island': 8.2,
#  'The Curious Case of Benjamin Button': 7.8,
#  'The Martian': 8.0,
#  'The Pursuit of Happyness': 8.0,
#  'The Truman Show': 8.2}

# %%
### Preliminary ranking

# PAIRS_NUM = 40

# movie_pairs = list(itertools.combinations(movies,2))
# movie_pairs = random.sample(movie_pairs, k=PAIRS_NUM)


# df = pd.DataFrame(movie_pairs)
# df['My choice'] = [0] * len(df)

# df

# %%
# for i, row in df.iterrows():
#     while True:
#         my_choice = int(input(f"(0): {row[0]:40} \t or \t (1): {row[1]}\n"))
#         if my_choice in [0,1]: break
        
#     df.loc[i, 'My choice'] = my_choice

# df.to_csv('my_rankings.csv')
# df

# %%
df = pd.read_csv('my_rankings.csv', index_col=0)
df
# Out:
#                                    left                                right  \
# 0                No Country for Old Men             The Pursuit of Happyness
# 1                           I Am Legend                       Shutter Island
# 2                           I Am Legend                          The Martian
# 3                           Cloud Atlas             The Pursuit of Happyness
# 4                           Cloud Atlas                          I Am Legend
# 5                          Interstellar         Rogue One: A Star Wars Story
# 6                           The Martian                       Shutter Island
# 7                        Shutter Island  The Curious Case of Benjamin Button
# 8          Rogue One: A Star Wars Story             The Pursuit of Happyness
# 9                          Interstellar                          Cloud Atlas
# 10                         Interstellar             The Pursuit of Happyness
# 11                      The Truman Show  The Curious Case of Benjamin Button
# 12                          The Martian  The Curious Case of Benjamin Button
# 13                       Shutter Island                      The Truman Show
# 14                      The Truman Show             The Pursuit of Happyness
# 15         Rogue One: A Star Wars Story               No Country for Old Men
# 16               No Country for Old Men  The Curious Case of Benjamin Button
# 17                          Cloud Atlas               No Country for Old Men
# 18                       Shutter Island             The Pursuit of Happyness
# 19                         Interstellar               No Country for Old Men
# 20         Rogue One: A Star Wars Story                       Shutter Island
# 21                          I Am Legend             The Pursuit of Happyness
# 22                          Cloud Atlas                      The Truman Show
# 23                          Cloud Atlas  The Curious Case of Benjamin Button
# 24               No Country for Old Men                       Shutter Island
# 25                         Interstellar  The Curious Case of Benjamin Button
# 26                         Interstellar                       Shutter Island
# 27               No Country for Old Men                      The Truman Show
# 28                         Interstellar                          I Am Legend
# 29                         Interstellar                      The Truman Show
# 30                          The Martian             The Pursuit of Happyness
# 31                          Cloud Atlas         Rogue One: A Star Wars Story
# 32                          I Am Legend  The Curious Case of Benjamin Button
# 33               No Country for Old Men                          The Martian
# 34         Rogue One: A Star Wars Story                          The Martian
# 35  The Curious Case of Benjamin Button             The Pursuit of Happyness
# 36                          I Am Legend               No Country for Old Men
# 37         Rogue One: A Star Wars Story  The Curious Case of Benjamin Button
# 38                          The Martian                      The Truman Show
# 39                          Cloud Atlas                       Shutter Island
#
#                                   label
# 0              The Pursuit of Happyness
# 1                        Shutter Island
# 2                           I Am Legend
# 3                           Cloud Atlas
# 4                           Cloud Atlas
# 5                          Interstellar
# 6                        Shutter Island
# 7   The Curious Case of Benjamin Button
# 8          Rogue One: A Star Wars Story
# 9                          Interstellar
# 10                         Interstellar
# 11  The Curious Case of Benjamin Button
# 12  The Curious Case of Benjamin Button
# 13                       Shutter Island
# 14             The Pursuit of Happyness
# 15         Rogue One: A Star Wars Story
# 16  The Curious Case of Benjamin Button
# 17                          Cloud Atlas
# 18                       Shutter Island
# 19                         Interstellar
# 20         Rogue One: A Star Wars Story
# 21                          I Am Legend
# 22                          Cloud Atlas
# 23                          Cloud Atlas
# 24                       Shutter Island
# 25                         Interstellar
# 26                         Interstellar
# 27               No Country for Old Men
# 28                         Interstellar
# 29                         Interstellar
# 30                          The Martian
# 31                          Cloud Atlas
# 32  The Curious Case of Benjamin Button
# 33               No Country for Old Men
# 34                          The Martian
# 35  The Curious Case of Benjamin Button
# 36                          I Am Legend
# 37         Rogue One: A Star Wars Story
# 38                      The Truman Show
# 39                          Cloud Atlas

# %%
agg_bt = BradleyTerry(n_iter=100).fit_predict(df)
agg_bt = dict(sorted(dict(agg_bt).items()))

agg_bt
# Out:
# {'Cloud Atlas': 0.21294335437769302,
#  'I Am Legend': 0.07125987497629856,
#  'Interstellar': 0.2659010917711591,
#  'No Country for Old Men': 0.026905942993819393,
#  'Rogue One: A Star Wars Story': 0.1114410266845456,
#  'Shutter Island': 0.10098147201177565,
#  'The Curious Case of Benjamin Button': 0.13475588345636055,
#  'The Martian': 0.033752746239306144,
#  'The Pursuit of Happyness': 0.026905942993819393,
#  'The Truman Show': 0.015152664495222573}

# %%
imdb_ratings = np.array(list(movies_imdb.values()))
imdb_ratings
# Out:
# array([7.4, 7.2, 8.7, 8.2, 7.8, 8.2, 7.8, 8. , 8. , 8.2])

# %%
agg_bt_ratings = np.array(list(agg_bt.values()))
agg_bt_ratings
# Out:
# array([0.21294335, 0.07125987, 0.26590109, 0.02690594, 0.11144103,
#        0.10098147, 0.13475588, 0.03375275, 0.02690594, 0.01515266])

# %%
stats.spearmanr(imdb_ratings, agg_bt_ratings)
# Out:
# SpearmanrResult(correlation=-0.18887712050782354, pvalue=0.6012580954612852)

# %% [markdown]
# ## Bootstrapping

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
BOOTSTRAP_ROUNDS = 1000
bs_res = []

k = 0
while k < BOOTSTRAP_ROUNDS:
    df_sample = df.sample(len(df), replace=True)

    agg_bt = BradleyTerry(n_iter=100).fit_predict(df_sample)
    agg_bt = dict(sorted(dict(agg_bt).items()))
    
    if len(list(agg_bt.values())) == len(movies_imdb):
        bs_res.append(list(agg_bt.values()))
        k += 1
        
        
bs_res = pd.DataFrame(bs_res).T

# %%
bs_res
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.219276  0.247112  0.246506  0.147099  0.198483  0.233975  0.196349
# 1  0.106653  0.132369  0.123780  0.031414  0.120478  0.070952  0.107341
# 2  0.226305  0.225224  0.238322  0.327967  0.219652  0.286723  0.242139
# 3  0.020740  0.056359  0.055812  0.031915  0.016823  0.012421  0.028510
# 4  0.191601  0.090483  0.119506  0.025120  0.034577  0.153817  0.097882
# 5  0.113454  0.037392  0.026488  0.127575  0.151453  0.079182  0.078002
# 6  0.075837  0.125234  0.088063  0.174697  0.166996  0.127159  0.220228
# 7  0.000000  0.045767  0.012782  0.025395  0.051171  0.000000  0.011198
# 8  0.046132  0.014136  0.066151  0.085339  0.000000  0.035772  0.000000
# 9  0.000000  0.025923  0.022590  0.023478  0.040366  0.000000  0.018352
#
#         7         8         9    ...       990       991       992       993  \
# 0  0.207908  0.198093  0.216576  ...  0.141931  0.262230  0.212096  0.193242
# 1  0.081187  0.041578  0.115603  ...  0.088655  0.069216  0.049287  0.097105
# 2  0.233428  0.234507  0.232642  ...  0.229136  0.260250  0.281460  0.224043
# 3  0.031765  0.060502  0.012050  ...  0.009906  0.063407  0.000000  0.096698
# 4  0.109234  0.047723  0.077278  ...  0.239614  0.101090  0.104738  0.069839
# 5  0.069565  0.233174  0.089808  ...  0.072514  0.081661  0.055450  0.120055
# 6  0.128877  0.137016  0.132695  ...  0.141135  0.058029  0.201395  0.128336
# 7  0.066609  0.047406  0.095287  ...  0.067171  0.034533  0.087521  0.052088
# 8  0.071428  0.000000  0.028060  ...  0.009937  0.049503  0.008054  0.008550
# 9  0.000000  0.000000  0.000000  ...  0.000000  0.020081  0.000000  0.010045
#
#         994       995       996       997       998       999
# 0  0.201387  0.216080  0.230403  0.217750  0.196947  0.233205
# 1  0.047440  0.068055  0.040193  0.061005  0.084679  0.031391
# 2  0.262895  0.257694  0.280641  0.269811  0.280492  0.243395
# 3  0.030115  0.022485  0.035723  0.059113  0.027060  0.060279
# 4  0.239020  0.142713  0.183701  0.131559  0.136912  0.108362
# 5  0.092552  0.086231  0.100534  0.077672  0.077990  0.126337
# 6  0.126591  0.131392  0.063425  0.170743  0.147956  0.109185
# 7  0.000000  0.038012  0.049959  0.000000  0.030271  0.026679
# 8  0.000000  0.037338  0.015420  0.000000  0.017694  0.026682
# 9  0.000000  0.000000  0.000000  0.012346  0.000000  0.034486
#
# [10 rows x 1000 columns]

# %%
bs_df = pd.DataFrame({'Movie': movies_imdb.keys(), 
                      '2.5% percentile': [0]*len(movies_imdb), 
                      '97.5% percentile': [0]*len(movies_imdb)})

for i, movie in enumerate(movies_imdb.keys()):
    bs_df.loc[i, '2.5% percentile'], bs_df.loc[i, '97.5% percentile'] = np.percentile(bs_res.iloc[i,:], [2.5, 97.5])

bs_df
# Out:
#                                  Movie  2.5% percentile  97.5% percentile
# 0                          Cloud Atlas         0.125285          0.272812
# 1                          I Am Legend         0.000000          0.162755
# 2                         Interstellar         0.208704          0.311784
# 3               No Country for Old Men         0.000000          0.082473
# 4         Rogue One: A Star Wars Story         0.024839          0.229733
# 5                       Shutter Island         0.032461          0.192477
# 6  The Curious Case of Benjamin Button         0.049622          0.224603
# 7                          The Martian         0.000000          0.124269
# 8             The Pursuit of Happyness         0.000000          0.080112
# 9                      The Truman Show         0.000000          0.064776
